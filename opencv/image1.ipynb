# %%
import cv2
import matplotlib.pyplot as plt

# %%
# read an image
img = cv2.imread('download.jpeg')# read as BGR instead of RGB

# %%
plt.imshow(img)
plt.show()

# %%
newimg = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(newimg)
plt.show()

# %%
print(img)
# Out:
# [[[240 231 222]
#   [240 231 222]
#   [240 231 222]
#   ...
#   [231 221 214]
#   [231 221 214]
#   [229 219 212]]
#
#  [[240 231 222]
#   [240 231 222]
#   [240 231 222]
#   ...
#   [231 221 214]
#   [231 221 214]
#   [229 219 212]]
#
#  [[240 231 222]
#   [240 231 222]
#   [240 231 222]
#   ...
#   [231 221 214]
#   [231 221 214]
#   [229 219 212]]
#
#  ...
#
#  [[ 83 108 124]
#   [ 83 108 124]
#   [ 83 108 124]
#   ...
#   [ 83 107 131]
#   [ 83 107 131]
#   [ 80 106 130]]
#
#  [[ 83 107 125]
#   [ 83 107 125]
#   [ 83 107 125]
#   ...
#   [ 83 107 131]
#   [ 83 107 131]
#   [ 80 106 130]]
#
#  [[ 83 106 128]
#   [ 83 106 128]
#   [ 83 106 128]
#   ...
#   [ 83 107 131]
#   [ 83 107 131]
#   [ 82 108 132]]]
